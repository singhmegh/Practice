# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/sumit/Downloads/titanic.csv")
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
new_data = data[["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked","Survived"]].copy()

# %%
new_data.head(3)
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Survived
# 0       3    0  22.0      1      0   7.2500         2         0
# 1       1    1  38.0      1      0  71.2833         0         1
# 2       3    1  26.0      0      0   7.9250         2         1

# %%
new_data.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Survived    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()
new_data["Age"] = si.fit_transform(new_data[["Age"]])

# %%
new_data["Embarked"] = new_data["Embarked"].fillna(new_data["Embarked"].mode()[0])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
new_data["Embarked"] = le.fit_transform(new_data["Embarked"])

# %%
age_en = {"male":0,"female":1}
new_data["Sex"] = new_data["Sex"].map(age_en)

# %%
x= new_data.iloc[:,:-1]
y=new_data["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
#Apply BaggingClassifier on Titanic dataset.
#Compare its accuracy with a single Decision Tree.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
bg = BaggingClassifier(estimator = dt,n_estimators =7)
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=7)

# %%
bg.score(x_train,y_train)*100 , bg.score(x_test,y_test)*100
# Out:
# (96.20786516853933, 80.44692737430168)

# %%
prd = bg.predict(x_test)

# %%
accuracy_score(y_test,prd)*100
# Out:
# 80.44692737430168
