# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/sumit/Downloads/titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 #Find the youngest female passenger who survived
female_p = data[(data["Sex"]=="female" ) & (data["Survived"] == 1)]
young_female = female_p.sort_values("Age").head(10)
young_female[["Name","Age","Survived","Pclass"]]
# Out:
#                                          Name   Age  Survived  Pclass
# 469             Baclini, Miss. Helene Barbara  0.75         1       3
# 644                    Baclini, Miss. Eugenie  0.75         1       3
# 381               Nakid, Miss. Maria ("Mary")  1.00         1       3
# 172              Johnson, Miss. Eleanor Ileen  1.00         1       3
# 530                  Quick, Miss. Phyllis May  2.00         1       2
# 479                  Hirvonen, Miss. Hildur E  2.00         1       3
# 43   Laroche, Miss. Simonne Marie Anne Andree  3.00         1       2
# 184       Kink-Heilmann, Miss. Luise Gretchen  4.00         1       3
# 750                         Wells, Miss. Joan  4.00         1       2
# 691                        Karun, Miss. Manca  4.00         1       3

# %%
#How many male passengers aged between 18 and 40 survived?
male_p = data[(data["Sex"] == "male") & (data["Survived"]==1) & (data["Age"]>=18) &(data["Age"]<= 40)]
print("Total male",len(male_p))
male_p[["Name","Age","Pclass","Sex"]]
# Out:
# Total male 52
#                                              Name   Age  Pclass   Sex
# 21                          Beesley, Mr. Lawrence  34.0       2  male
# 23                   Sloper, Mr. William Thompson  28.0       1  male
# 74                                  Bing, Mr. Lee  32.0       3  male
# 81                    Sheerlinck, Mr. Jan Baptist  29.0       3  male
# 97                Greenfield, Mr. William Bertram  23.0       1  male
# 127                     Madsen, Mr. Fridtjof Arne  24.0       3  male
# 146  Andersson, Mr. August Edvard ("Wennerstrom")  27.0       3  male
# 204                      Cohen, Mr. Gurshon "Gus"  18.0       3  male
# 207                   Albimona, Mr. Nassef Cassem  26.0       3  male
# 209                              Blank, Mr. Henry  40.0       1  male
# 224                  Hoyt, Mr. Frederick Maxfield  38.0       1  male
# 226                     Mellors, Mr. William John  19.0       2  male
# ...

# %%
#Count the number of passengers who had a fare above the average fare.

avg_fare = data["Fare"].mean()
above_avg_fare= data[data["Fare"]>avg_fare]
above_avg_fare[["Name","Sex","Pclass","Fare"]]
# Out:
#                                                   Name     Sex  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 6                              McCarthy, Mr. Timothy J    male       1
# 23                        Sloper, Mr. William Thompson    male       1
# 27                      Fortune, Mr. Charles Alexander    male       1
# ..                                                 ...     ...     ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female       1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female       3
# 867               Roebling, Mr. Washington Augustus II    male       1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female       1
#
#          Fare
# 1     71.2833
# 3     53.1000
# 6     51.8625
# 23    35.5000
# 27   263.0000
# ..        ...
# ...

# %%
#Create a bar plot showing the number of survivors by Embarked location

survivor = data[data["Survived"]==1]
survivors_counts = survivor["Embarked"].value_counts().sort_index()

plt.figure(figsize=(5,4))
survivors_counts.plot(kind="bar",color='skyblue', edgecolor='black')
plt.title("Number of survivors by Embarked location")
plt.ylabel("Survivors")
plt.xlabel("Embarked location")
plt.show()

# %%
#Display passengers who:
#Had no siblings/spouse and no parents/children (SibSp == 0 and Parch == 0)
#Were in 3rd class
#And did not survive

# %%
passengers = data[(data["SibSp"]==0)&(data["Parch"]==0)&(data["Pclass"]==3)&(data["Survived"]==0)]
passengers[["Name","Sex","Pclass"]]
# Out:
#                                      Name     Sex  Pclass
# 4                Allen, Mr. William Henry    male       3
# 5                        Moran, Mr. James    male       3
# 12         Saundercock, Mr. William Henry    male       3
# 14   Vestrom, Miss. Hulda Amanda Adolfina  female       3
# 26                Emir, Mr. Farred Chehab    male       3
# ..                                    ...     ...     ...
# 878                    Laleff, Mr. Kristo    male       3
# 881                    Markun, Mr. Johann    male       3
# 882          Dahlberg, Miss. Gerda Ulrika  female       3
# 884                Sutehall, Mr. Henry Jr    male       3
# 890                   Dooley, Mr. Patrick    male       3
#
# [255 rows x 3 columns]
